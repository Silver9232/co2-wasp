# %% [markdown]
# # Import Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data - $R^2$

# %%
sag_lhs = pd.read_csv("results/sag_7_lhs.csv")
sag_ran = pd.read_csv("results/sag_7_ran.csv")
# wag_oil = pd.read_csv("wag_oilproduced.csv")
# wag_gas = pd.read_csv("wag_gasproduced.csv")
# sag_oil = pd.read_csv("sag_oilprod.csv")
# sag_gas = pd.read_csv("sag_gasprod.csv")

display(sag_lhs)
display(sag_ran)
# Out:
#    Unnamed: 0 Models  test_qg_R²_test  test_qo_R²_test  val_qg_R²_test  \
# 0           0     DT         0.976950         0.989119             NaN
# 1           1    GBR         0.991630         0.996457             NaN
# 2           2    KNN         0.991468         0.996069             NaN
# 3           3     RF         0.989653         0.995347             NaN
#
#    val_qo_R²_test  test_qg_RMSE_test  test_qo_RMSE_test  val_qg_RMSE_test  \
# 0             NaN      318854.040736      298428.389133               NaN
# 1             NaN      192147.702815      170282.153060               NaN
# 2             NaN      193991.260300      179374.617679               NaN
# 3             NaN      213636.157728      195154.284752               NaN
#
#    val_qo_RMSE_test  test_qg_R²_val  test_qo_R²_val  val_qg_R²_val  \
# 0               NaN             NaN             NaN       0.969656
# 1               NaN             NaN             NaN       0.986671
# 2               NaN             NaN             NaN       0.986087
# 3               NaN             NaN             NaN       0.987429
#
#    val_qo_R²_val  test_qg_RMSE_val  test_qo_RMSE_val  val_qg_RMSE_val  \
# 0       0.991611               NaN               NaN    345846.629676
# 1       0.995723               NaN               NaN    229214.914375
# 2       0.993309               NaN               NaN    234181.231370
# 3       0.994494               NaN               NaN    222605.827839
#
#    val_qo_RMSE_val
# 0    257406.207849
# 1    183795.208790
# 2    229878.672147
# 3    208532.139099
#    Unnamed: 0 Models  test_qg_R²_test  test_qo_R²_test  val_qg_R²_test  \
# 0           0     DT         0.976950         0.989119             NaN
# 1           1    GBR         0.991627         0.996456             NaN
# 2           2    KNN         0.991468         0.996069             NaN
# 3           3     RF         0.989653         0.995347             NaN
#
#    val_qo_R²_test  test_qg_RMSE_test  test_qo_RMSE_test  val_qg_RMSE_test  \
# 0             NaN      318854.040736      298428.389133               NaN
# 1             NaN      192178.832254      170310.497004               NaN
# 2             NaN      193991.260300      179374.617679               NaN
# 3             NaN      213636.157728      195154.284752               NaN
#
#    val_qo_RMSE_test  test_qg_R²_val  test_qo_R²_val  val_qg_R²_val  \
# 0               NaN             NaN             NaN       0.969656
# 1               NaN             NaN             NaN       0.986674
# 2               NaN             NaN             NaN       0.986087
# 3               NaN             NaN             NaN       0.987429
#
#    val_qo_R²_val  test_qg_RMSE_val  test_qo_RMSE_val  val_qg_RMSE_val  \
# 0       0.991611               NaN               NaN    345846.629676
# 1       0.995723               NaN               NaN    229189.951884
# 2       0.993309               NaN               NaN    234181.231370
# 3       0.994494               NaN               NaN    222605.827839
#
#    val_qo_RMSE_val
# 0    257406.207849
# 1    183795.208790
# 2    229878.672147
# 3    208532.139099

# %% [markdown]
# # Import Data - $RMSE$

# %%
sag_lhs_f = pd.read_csv("results/sag_7_lhs.csv")
sag_ran_f = pd.read_csv("results/sag_7_ran.csv")
# wag_ran_ran = pd.read_csv("wag_ran_ran.csv")
# wag_lhs_ran = pd.read_csv("wag_lhs_ran.csv")
# wag_ran_gr = pd.read_csv("wag_ran_gr.csv")
# wag_lhs_gr = pd.read_csv("wag_lhs_gr.csv")
# wag_ran_pso = pd.read_csv("wag_ran_pso.csv")
# wag_lhs_pso = pd.read_csv("wag_lhs_pso.csv")

custom_order = [2, 1, 0, 3]

sag_lhs_f = sag_lhs_f.iloc[:, 1:]
sag_ran_f = sag_ran_f.iloc[:, 1:]
# wag_ran_ran = wag_ran_ran.iloc[:, 1:]
# wag_lhs_ran = wag_lhs_ran.iloc[:, 1:]
# wag_ran_gr = wag_ran_gr.iloc[:, 1:]
# wag_lhs_gr = wag_lhs_gr.iloc[:, 1:]
# wag_ran_pso = wag_ran_pso.iloc[:, 1:]
# wag_lhs_pso = wag_lhs_pso.iloc[:, 1:]

sag_lhs_f = sag_lhs_f.reindex(custom_order)
sag_ran_f = sag_ran_f.reindex(custom_order)
# wag_ran_ran = wag_ran_ran.reindex(custom_order)
# wag_lhs_ran = wag_lhs_ran.reindex(custom_order)
# wag_ran_gr = wag_ran_gr.reindex(custom_order)
# wag_lhs_gr = wag_lhs_gr.reindex(custom_order)
# wag_ran_pso = wag_ran_pso.reindex(custom_order)
# wag_lhs_pso = wag_lhs_pso.reindex(custom_order)

print(sag_lhs_f)
# Out:
#   Models  test_qg_R²_test  test_qo_R²_test  val_qg_R²_test  val_qo_R²_test  \
# 2    KNN         0.991468         0.996069             NaN             NaN
# 1    GBR         0.991630         0.996457             NaN             NaN
# 0     DT         0.976950         0.989119             NaN             NaN
# 3     RF         0.989653         0.995347             NaN             NaN
#
#    test_qg_RMSE_test  test_qo_RMSE_test  val_qg_RMSE_test  val_qo_RMSE_test  \
# 2      193991.260300      179374.617679               NaN               NaN
# 1      192147.702815      170282.153060               NaN               NaN
# 0      318854.040736      298428.389133               NaN               NaN
# 3      213636.157728      195154.284752               NaN               NaN
#
#    test_qg_R²_val  test_qo_R²_val  val_qg_R²_val  val_qo_R²_val  \
# 2             NaN             NaN       0.986087       0.993309
# 1             NaN             NaN       0.986671       0.995723
# 0             NaN             NaN       0.969656       0.991611
# 3             NaN             NaN       0.987429       0.994494
#
#    test_qg_RMSE_val  test_qo_RMSE_val  val_qg_RMSE_val  val_qo_RMSE_val
# 2               NaN               NaN    234181.231370    229878.672147
# 1               NaN               NaN    229214.914375    183795.208790
# 0               NaN               NaN    345846.629676    257406.207849
# 3               NaN               NaN    222605.827839    208532.139099

# %%
names = {"KNN":"KNN", "Gradiente Boosting Regressor":"GBR", "Decision Tree":"DT", "Random Forest":"RF"}

wag_lhs["Models"] = wag_lhs["Models"].map(names)
wag_ran["Models"] = wag_ran["Models"].map(names)
wag_oil["Models"] = wag_oil["Models"].map(names)
wag_gas["Models"] = wag_gas["Models"].map(names)
sag_oil["Models"] = sag_oil["Models"].map(names)
sag_gas["Models"] = sag_gas["Models"].map(names)

# %%
display(wag_oil)
display(wag_gas)
display(sag_oil)
display(sag_gas)
# Out:
#   Models  $R^{2}test_Ran$  $R^{2}val_Ran$  $R^{2}test_Grid$  $R^{2}val_Grid$  \
# 0    KNN         0.993544        0.986710          0.993544         0.986710
# 1    GBR         0.997140        0.997773          0.997137         0.997769
# 2     DT         0.990805        0.993696          0.989587         0.996109
# 3     RF         0.992328        0.996258          0.992328         0.996258
#
#    $R^{2}test_PSO$  $R^{2}val_PSO$
# 0         0.993544        0.986710
# 1         0.996682        0.996939
# 2         0.988544        0.993344
# 3         0.992467        0.995360
#   Models  $R^{2}test$  $R^{2}val$  $R^{2}test_Ran$  $R^{2}val_Ran$  \
# 0    KNN     0.944044    0.949833         0.933324        0.940919
# 1    GBR     0.974586    0.952050         0.976557        0.951869
# 2     DT     0.919528    0.663891         0.938895        0.940339
# 3     RF     0.944450    0.912405         0.944450        0.912405
#
#    $R^{2}test_Grid$  $R^{2}val_Grid$
# 0          0.933324         0.940919
# 1          0.976527         0.951915
# 2          0.932821         0.694636
# 3          0.944450         0.912405
#   Models  $R^{2}test_Ran$  $R^{2}val_Ran$  $R^{2}test_Grid$  $R^{2}val_Grid$  \
# 0    KNN         0.987947        0.984181          0.987947         0.984181
# 1    GBR         0.991203        0.997624          0.991078         0.997542
# 2     DT         0.961947        0.976055          0.970646         0.979961
# 3     RF         0.982754        0.985752          0.982754         0.985752
#
#    $R^{2}test_PSO$  $R^{2}val_PSO$
# 0         0.987947        0.984181
# 1         0.991100        0.997558
# 2         0.965698        0.979564
# 3         0.985414        0.986961
#   Models  $R^{2}test_Ran$  $R^{2}val_Ran$  $R^{2}test_Grid$  $R^{2}val_Grid$  \
# 0    KNN         0.982160        0.959546          0.982160         0.959546
# 1    GBR         0.990437        0.966800          0.990717         0.966759
# 2     DT         0.955163        0.882932          0.953533         0.885487
# 3     RF         0.976430        0.924967          0.976430         0.924967
#
#    $R^{2}test_PSO$  $R^{2}val_PSO$
# 0         0.982160        0.959546
# 1         0.990698        0.966721
# 2         0.960712        0.919926
# 3         0.977981        0.931781

# %%
sag_ran_f
# Out:
#   Models  test_qg_R²_test  test_qo_R²_test  val_qg_R²_test  val_qo_R²_test  \
# 2    KNN         0.990847         0.996629             NaN             NaN
# 1    GBR         0.989228         0.997234             NaN             NaN
# 0     DT         0.971463         0.990955             NaN             NaN
# 3     RF         0.993309         0.996588             NaN             NaN
#
#    test_qg_RMSE_test  test_qo_RMSE_test  val_qg_RMSE_test  val_qo_RMSE_test  \
# 2      201237.103388      175718.599181               NaN               NaN
# 1      218310.598535      159191.008110               NaN               NaN
# 0      355335.641853      287847.981300               NaN               NaN
# 3      172063.714479      176794.446754               NaN               NaN
#
#    test_qg_R²_val  test_qo_R²_val  val_qg_R²_val  val_qo_R²_val  \
# 2             NaN             NaN       0.991239       0.994995
# 1             NaN             NaN       0.985985       0.995598
# 0             NaN             NaN       0.960573       0.966794
# 3             NaN             NaN       0.983919       0.993770
#
#    test_qg_RMSE_val  test_qo_RMSE_val  val_qg_RMSE_val  val_qo_RMSE_val
# 2               NaN               NaN    188598.508410    171533.013617
# 1               NaN               NaN    238542.148266    160877.684290
# 0               NaN               NaN    400091.654754    441851.926709
# 3               NaN               NaN    255516.899743    191391.215941

# %% [markdown]
# # EDA CO2 Retained - R2

# %%
# Filter data for "No-opt" models
no_opt_ran = wag_ran_f.iloc[:, [0, 1, 13]]  # Models, R^2 test, R^2 train (No-opt only)
no_opt_lhs = wag_lhs_f.iloc[:, [0, 1, 13]]

# Extract model names and their corresponding values
models = no_opt_ran['Models'].values
r2_test_ran = no_opt_ran.iloc[:, 1].values  # Test values
r2_val_ran = no_opt_ran.iloc[:, 2].values  # Validation values
r2_test_lhs = no_opt_lhs.iloc[:, 1].values
r2_val_lhs = no_opt_lhs.iloc[:, 2].values

# Define bar positions
x_pos = np.arange(len(models))
bar_width = 0.35

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Left subplot: results_ran
axes[0].bar(x_pos - bar_width/2, r2_test_ran, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, r2_val_ran, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Model', fontsize=18)
axes[0].set_ylabel('$R^{2}$ Score', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(models, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_ran
for bars in [axes[0].patches[:len(models)], axes[0].patches[len(models):]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_lhs
axes[1].bar(x_pos - bar_width/2, r2_test_lhs, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, r2_val_lhs, bar_width, label='Train', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Model', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(models, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)

# Annotate bars for results_lhs
for bars in [axes[1].patches[:len(models)], axes[1].patches[len(models):]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("no_opt_model_comparison_ran_lhs.png", dpi=300, format='png', bbox_inches='tight')
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# Extract data for KNN model (assuming it's the first row in both DataFrames)
# gbr_results_ran = wag_ran.iloc[1, 1:]  # Skip the "Models" column
# gbr_results_lhs = wag_lhs.iloc[1, 1:]

# Define test and validation data for both datasets
rmse_test_ran = np.array([wag_ran_f.iloc[1, 7], wag_ran_ran.iloc[1, 7], wag_ran_gr.iloc[1, 7]])  # Test results
r2_val_ran = gbr_results_ran[1::2].values  # Validation results
r2_test_lhs = gbr_results_lhs[::2].values
r2_val_lhs = gbr_results_lhs[1::2].values

# Define optimization methods and bar positions
opt_methods = ["No-opt", "Random", "Grid", "PSO"]
x_pos = np.arange(len(opt_methods))

# Set up Matplotlib figure and subplots
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Optimization Method', fontsize=18)
axes[0].set_ylabel('$R^{2}$ Score', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(opt_methods, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_ran
for bars in [axes[0].patches[:4], axes[0].patches[4:]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_lhs
axes[1].bar(x_pos - bar_width/2, r2_test_lhs, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, r2_val_lhs, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Optimization Method', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(opt_methods, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)

# Annotate bars for results_lhs
for bars in [axes[1].patches[:4], axes[1].patches[4:]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("gbr_model_comparison_ran_lhs.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # EDA CO2 Retained - RMSE

# %%
# Filter data for "No-opt" models
no_opt_ran = sag_ran_f.iloc[:, [0, 5, 15]]  # Models, R^2 test, R^2 train (No-opt only)
no_opt_lhs = sag_lhs_f.iloc[:, [0, 5, 15]]

# Extract model names and their corresponding values
models = no_opt_ran['Models'].values
rmse_test_ran = no_opt_ran.iloc[:, 1].values / 1000 # Test values
rmse_val_ran = no_opt_ran.iloc[:, 2].values / 1000 # Validation values
rmse_test_lhs = no_opt_lhs.iloc[:, 1].values / 1000
rmse_val_lhs = no_opt_lhs.iloc[:, 2].values / 1000

# Define bar positions
x_pos = np.arange(len(models))
bar_width = 0.35

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Left subplot: results_ran
axes[0].bar(x_pos - bar_width/2, rmse_test_ran, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, rmse_val_ran, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Model', fontsize=18)
axes[0].set_ylabel('$RMSE (MSCF)$', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(models, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_ran
for bars in [axes[0].patches[:len(models)], axes[0].patches[len(models):]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.2f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_lhs
axes[1].bar(x_pos - bar_width/2, rmse_test_lhs, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, rmse_val_lhs, bar_width, label='Train', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Model', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(models, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)

# Annotate bars for results_lhs
for bars in [axes[1].patches[:len(models)], axes[1].patches[len(models):]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.2f}', 
                     ha='center', va='bottom', fontsize=14)

# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("plots/no_opt_model_comparison_ran_lhs_rmse_7.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Extract data for KNN model (assuming it's the first row in both DataFrames)
# gbr_results_ran = wag_ran.iloc[1, 1:]  # Skip the "Models" column
# gbr_results_lhs = wag_lhs.iloc[1, 1:]

# Define test and validation data for both datasets
rmse_test_ran = np.array([wag_ran_f.iloc[1, 7], wag_ran_ran.iloc[1, 7], wag_ran_gr.iloc[1, 7], wag_ran_pso.iloc[1, 7]]) / 1000  # Test results
rmse_val_ran = np.array([wag_ran_f.iloc[1, 22], wag_ran_ran.iloc[1, 22], wag_ran_gr.iloc[1, 22], wag_ran_pso.iloc[1, 22]]) / 1000 # Validation results
rmse_test_lhs = np.array([wag_lhs_f.iloc[1, 7], wag_lhs_ran.iloc[1, 7], wag_lhs_gr.iloc[1, 7], wag_lhs_pso.iloc[1, 7]]) / 1000
rmse_val_lhs = np.array([wag_lhs_f.iloc[1, 22], wag_lhs_ran.iloc[1, 22], wag_lhs_gr.iloc[1, 22], wag_lhs_pso.iloc[1, 22]]) / 1000

# Define optimization methods and bar positions
opt_methods = ["No-opt", "Random", "Grid", "PSO"]
x_pos = np.arange(len(opt_methods))

bar_width = 0.35

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Set up Matplotlib figure and subplots
axes[0].bar(x_pos - bar_width/2, rmse_test_ran, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, rmse_val_ran, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Optimization Method', fontsize=18)
axes[0].set_ylabel('$RMSE (MSCF)$', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(opt_methods, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_ran
for bars in [axes[0].patches[:4], axes[0].patches[4:]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.2f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_lhs
axes[1].bar(x_pos - bar_width/2, rmse_test_lhs, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, rmse_val_lhs, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Optimization Method', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(opt_methods, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)

# Annotate bars for results_lhs
for bars in [axes[1].patches[:4], axes[1].patches[4:]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.2f}', 
                     ha='center', va='bottom', fontsize=14)

# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("gbr_model_comparison_ran_lhs_rmse.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # EDA Oil & Gas (WAG)

# %%
# Extract data for GBR model (assuming it's the first row in both DataFrames)
gbr_results_oil = wag_oil.iloc[1, 1:]  # Skip the "Models" column
gbr_results_gas = wag_gas.iloc[1, 1:]

# Define test and validation data for both datasets
r2_test_oil = gbr_results_oil[::2].values  # Test results
r2_val_oil = gbr_results_gas[1::2].values  # Validation results
r2_test_gas = gbr_results_oil[::2].values
r2_val_gas = gbr_results_gas[1::2].values

# Define optimization methods and bar positions
opt_methods = ["Random", "Grid", "PSO"]
x_pos = np.arange(len(opt_methods))

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Bar width and spacing
bar_width = 0.4

# Left subplot: results_oil
axes[0].bar(x_pos - bar_width/2, r2_test_oil, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, r2_val_oil, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Optimization Method', fontsize=18)
axes[0].set_ylabel('$R^{2}$ Score', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(opt_methods, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc="lower left", fontsize=16)

# Annotate bars for results_oil
for bars in [axes[0].patches[:3], axes[0].patches[3:]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_gas
axes[1].bar(x_pos - bar_width/2, r2_test_gas, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, r2_val_gas, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Optimization Method', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(opt_methods, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)
#axes[1].legend(loc="lower left", fontsize=12)

# Annotate bars for results_gas
for bars in [axes[1].patches[:3], axes[1].patches[3:]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)


# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("wag_oil_gas.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # EDA Oil & Gas (SAG)

# %%
# Extract data for GBR model (assuming it's the first row in both DataFrames)
gbr_results_oil = sag_oil.iloc[1, 1:]  # Skip the "Models" column
gbr_results_gas = sag_gas.iloc[1, 1:]

# Define test and validation data for both datasets
r2_test_oil = gbr_results_oil[::2].values  # Test results
r2_val_oil = gbr_results_gas[1::2].values  # Validation results
r2_test_gas = gbr_results_oil[::2].values
r2_val_gas = gbr_results_gas[1::2].values

# Define optimization methods and bar positions
opt_methods = ["Random", "Grid", "PSO"]
x_pos = np.arange(len(opt_methods))

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Bar width and spacing
bar_width = 0.4

# Left subplot: results_oil
axes[0].bar(x_pos - bar_width/2, r2_test_oil, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, r2_val_oil, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Optimization Method', fontsize=18)
axes[0].set_ylabel('$R^{2}$ Score', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(opt_methods, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_oil
for bars in [axes[0].patches[:3], axes[0].patches[3:]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_gas
axes[1].bar(x_pos - bar_width/2, r2_test_gas, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, r2_val_gas, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Optimization Method', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(opt_methods, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)
#axes[1].legend(loc=0, fontsize=12)

# Annotate bars for results_gas
for bars in [axes[1].patches[:3], axes[1].patches[3:]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)


# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("sag_oil_gas.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
