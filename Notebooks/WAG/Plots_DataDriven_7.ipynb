# %% [markdown]
# # Import Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data - $R^2$

# %%
wag_lhs = pd.read_csv("results/wag_7_lhs.csv")
wag_ran = pd.read_csv("results/wag_7_ran.csv")
wag_ran_lhs = pd.read_csv("results/wag_7_lhs_ran.csv")
wag_ran_ran = pd.read_csv("results/wag_7_ran_ran.csv")
wag_gr_lhs = pd.read_csv("results/wag_7_lhs_gr.csv")
wag_gr_ran = pd.read_csv("results/wag_7_ran_gr.csv")
wag_pso_lhs = pd.read_csv("results/wag_7_lhs_pso.csv")
wag_pso_ran = pd.read_csv("results/wag_7_ran_pso.csv")

sag_lhs = pd.read_csv("results/sag_7_lhs.csv")
sag_ran = pd.read_csv("results/sag_7_ran.csv")
sag_ran_lhs = pd.read_csv("results/sag_7_lhs_ran.csv")
sag_ran_ran = pd.read_csv("results/sag_7_ran_ran.csv")
sag_gr_lhs = pd.read_csv("results/sag_7_lhs_gr.csv")
sag_gr_ran = pd.read_csv("results/sag_7_ran_gr.csv")
sag_pso_lhs = pd.read_csv("results/sag_7_lhs_pso.csv")
sag_pso_ran = pd.read_csv("results/sag_7_ran_pso.csv")


display(wag_lhs)
display(wag_ran)
# Out:
#    Unnamed: 0 Models  test_cs_R²_test  test_qg_R²_test  test_qo_R²_test  \
# 0           0     DT         0.985707         0.980164         0.996128
# 1           1    GBR         0.992018         0.991118         0.997239
# 2           2    KNN         0.972529         0.988825         0.997176
# 3           3     RF         0.991558         0.995343         0.996382
#
#    val_cs_R²_test  val_qg_R²_test  val_qo_R²_test  test_cs_RMSE_test  \
# 0             NaN             NaN             NaN       63216.499314
# 1             NaN             NaN             NaN       47241.473212
# 2             NaN             NaN             NaN       87641.694037
# 3             NaN             NaN             NaN       48584.180157
#
#    test_qg_RMSE_test  ...  test_qo_R²_val  val_cs_R²_val  val_qg_R²_val  \
# 0      362944.610711  ...             NaN       0.973761       0.989606
# 1      242867.062550  ...             NaN       0.993211       0.992326
# ...

# %% [markdown]
# # Import Data - $RMSE$

# %%
custom_order = [2, 1, 0, 3]

wag_lhs = wag_lhs.iloc[:, 1:]
wag_ran = wag_ran.iloc[:, 1:]
sag_lhs = sag_lhs.iloc[:, 1:]
sag_ran = sag_ran.iloc[:, 1:]

wag_ran_ran = wag_ran_ran.iloc[:, 1:]
wag_ran_lhs = wag_ran_lhs.iloc[:, 1:]
wag_gr_ran = wag_gr_ran.iloc[:, 1:]
wag_gr_lhs = wag_gr_lhs.iloc[:, 1:]
wag_pso_ran = wag_pso_ran.iloc[:, 1:]
wag_pso_lhs = wag_pso_lhs.iloc[:, 1:]
sag_ran_ran = sag_ran_ran.iloc[:, 1:]
sag_ran_lhs = sag_ran_lhs.iloc[:, 1:]
sag_gr_ran = sag_gr_ran.iloc[:, 1:]
sag_gr_lhs = sag_gr_lhs.iloc[:, 1:]
sag_pso_ran = sag_pso_ran.iloc[:, 1:]
sag_pso_lhs = sag_pso_lhs.iloc[:, 1:]

wag_lhs = wag_lhs.reindex(custom_order)
wag_ran = wag_ran.reindex(custom_order)
sag_lhs = sag_lhs.reindex(custom_order)
sag_ran = sag_ran.reindex(custom_order)

# wag_ran_ran = wag_ran_ran.reindex(custom_order)
# wag_lhs_ran = wag_lhs_ran.reindex(custom_order)
# wag_ran_gr = wag_ran_gr.reindex(custom_order)
# wag_lhs_gr = wag_lhs_gr.reindex(custom_order)
# wag_ran_pso = wag_ran_pso.reindex(custom_order)
# wag_lhs_pso = wag_lhs_pso.reindex(custom_order)
# sag_ran_ran = sag_ran_ran.reindex(custom_order)
# sag_lhs_ran = sag_lhs_ran.reindex(custom_order)
# sag_ran_gr = sag_ran_gr.reindex(custom_order)
# sag_lhs_gr = sag_lhs_gr.reindex(custom_order)
# sag_ran_pso = sag_ran_pso.reindex(custom_order)
# sag_lhs_pso = sag_lhs_pso.reindex(custom_order)

print(wag_lhs)
# Out:
#   Models  test_cs_R²_test  test_qg_R²_test  test_qo_R²_test  val_cs_R²_test  \
# 2    KNN         0.972529         0.988825         0.997176             NaN
# 1    GBR         0.992018         0.991118         0.997239             NaN
# 0     DT         0.985707         0.980164         0.996128             NaN
# 3     RF         0.991558         0.995343         0.996382             NaN
#
#    val_qg_R²_test  val_qo_R²_test  test_cs_RMSE_test  test_qg_RMSE_test  \
# 2             NaN             NaN       87641.694037      272417.583029
# 1             NaN             NaN       47241.473212      242867.062550
# 0             NaN             NaN       63216.499314      362944.610711
# 3             NaN             NaN       48584.180157      175862.352117
#
#    test_qo_RMSE_test  ...  test_qo_R²_val  val_cs_R²_val  val_qg_R²_val  \
# 2      159520.099093  ...             NaN       0.968875       0.983040
# 1      157720.535852  ...             NaN       0.993211       0.992326
# ...

# %%
wag_ran
# Out:
#   Models  test_cs_R²_test  test_qg_R²_test  test_qo_R²_test  val_cs_R²_test  \
# 2    KNN         0.976929         0.989351         0.996748             NaN
# 1    GBR         0.995471         0.988166         0.998538             NaN
# 0     DT         0.982043         0.976811         0.997274             NaN
# 3     RF         0.991852         0.991870         0.997703             NaN
#
#    val_qg_R²_test  val_qo_R²_test  test_cs_RMSE_test  test_qg_RMSE_test  \
# 2             NaN             NaN       78437.065152      261989.655461
# 1             NaN             NaN       34752.774753      276175.328729
# 0             NaN             NaN       69198.405840      386600.687312
# 3             NaN             NaN       46613.067642      228911.382553
#
#    test_qo_RMSE_test  ...  test_qo_R²_val  val_cs_R²_val  val_qg_R²_val  \
# 2      180665.141043  ...             NaN       0.980401       0.983754
# 1      121145.719309  ...             NaN       0.994834       0.983460
# ...

# %% [markdown]
# # EDA CO2 Retained - R2

# %%
# Filter data for "No-opt" models
no_opt_ran = wag_ran.iloc[:, [0, 1, 16]]  # Models, R^2 test, R^2 validation (No-opt only)
no_opt_lhs = wag_lhs.iloc[:, [0, 1, 16]]

# Extract model names and their corresponding values
models = no_opt_ran['Models'].values
r2_test_ran = no_opt_ran.iloc[:, 1].values  # Test values
r2_val_ran = no_opt_ran.iloc[:, 2].values  # Validation values
r2_test_lhs = no_opt_lhs.iloc[:, 1].values
r2_val_lhs = no_opt_lhs.iloc[:, 2].values

# Define bar positions
x_pos = np.arange(len(models))
bar_width = 0.35

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Left subplot: results_ran
axes[0].bar(x_pos - bar_width/2, r2_test_ran, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, r2_val_ran, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Model', fontsize=18)
axes[0].set_ylabel('$R^{2}$ Score', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(models, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_ran
for bars in [axes[0].patches[:len(models)], axes[0].patches[len(models):]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_lhs
axes[1].bar(x_pos - bar_width/2, r2_test_lhs, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, r2_val_lhs, bar_width, label='Train', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Model', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(models, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)

# Annotate bars for results_lhs
for bars in [axes[1].patches[:len(models)], axes[1].patches[len(models):]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("Plots/no_opt_model_comparison_ran_lhs.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
wag_pso_ran
# Out:
#   Models  test_cs_R²_test  test_qg_R²_test  test_qo_R²_test  val_cs_R²_test  \
# 0     DT         0.981183         0.977186         0.997423             NaN
# 1    GBR         0.996116         0.992840         0.998714             NaN
# 2    KNN         0.984550         0.993019         0.996480             NaN
# 3     RF         0.991174         0.991939         0.997584             NaN
#
#    val_qg_R²_test  val_qo_R²_test  test_cs_RMSE_test  test_qg_RMSE_test  \
# 0             NaN             NaN       70837.677144      383465.424175
# 1             NaN             NaN       32182.044755      214825.297794
# 2             NaN             NaN       64187.675763      212113.774331
# 3             NaN             NaN       48514.147911      227942.337591
#
#    test_qo_RMSE_test  ...  test_qo_R²_val  val_cs_R²_val  val_qg_R²_val  \
# 0      160839.316269  ...             NaN       0.987374       0.978307
# 1      113633.703899  ...             NaN       0.995396       0.989173
# ...

# %%
# Extract data for KNN model (assuming it's the first row in both DataFrames)
# gbr_results_ran = wag_ran.iloc[1, 1:]  # Skip the "Models" column
# gbr_results_lhs = wag_lhs.iloc[1, 1:]

# Define test and validation data for both datasets
r2_test_ran = np.array([wag_ran.iloc[1, 1], wag_ran_ran.iloc[1, 1], wag_gr_ran.iloc[1, 1], wag_pso_ran.iloc[1, 1]])  # Test results
r2_val_ran = np.array([wag_ran.iloc[1, 16], wag_ran_ran.iloc[1, 16], wag_gr_ran.iloc[1, 16], wag_pso_ran.iloc[1, 16]])  # Validation results
r2_test_lhs = np.array([wag_lhs.iloc[1, 1], wag_ran_lhs.iloc[1, 1], wag_gr_lhs.iloc[1, 1], wag_pso_lhs.iloc[1, 1]])
r2_val_lhs = np.array([wag_lhs.iloc[1, 16], wag_ran_lhs.iloc[1, 16], wag_gr_lhs.iloc[1, 16], wag_pso_lhs.iloc[1, 16]]) 

# Define optimization methods and bar positions
opt_methods = ["No-opt", "Random", "Grid", "PSO"]
x_pos = np.arange(len(opt_methods))

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Left subplot: results_ran
axes[0].bar(x_pos - bar_width/2, r2_test_ran, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, r2_val_ran, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Optimization Method', fontsize=18)
axes[0].set_ylabel('$R^{2}$ Score', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(opt_methods, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_ran
for bars in [axes[0].patches[:4], axes[0].patches[4:]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_lhs
axes[1].bar(x_pos - bar_width/2, r2_test_lhs, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, r2_val_lhs, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Optimization Method', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(opt_methods, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)

# Annotate bars for results_lhs
for bars in [axes[1].patches[:4], axes[1].patches[4:]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("Plots/gbr_model_comparison_ran_lhs.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # EDA CO2 Retained - RMSE

# %%
# Filter data for "No-opt" models
no_opt_ran = wag_ran.iloc[:, [0, 7, 22]]  # Models, RMSE test, RMSE validation (No-opt only)
no_opt_lhs = wag_lhs.iloc[:, [0, 7, 22]]

# Extract model names and their corresponding values
models = no_opt_ran['Models'].values
rmse_test_ran = no_opt_ran.iloc[:, 1].values / 1000 # Test values
rmse_val_ran = no_opt_ran.iloc[:, 2].values / 1000 # Validation values
rmse_test_lhs = no_opt_lhs.iloc[:, 1].values / 1000
rmse_val_lhs = no_opt_lhs.iloc[:, 2].values / 1000

# Define bar positions
x_pos = np.arange(len(models))
bar_width = 0.35

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Left subplot: results_ran
axes[0].bar(x_pos - bar_width/2, rmse_test_ran, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, rmse_val_ran, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Model', fontsize=18)
axes[0].set_ylabel('$RMSE (MSCF)$', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(models, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_ran
for bars in [axes[0].patches[:len(models)], axes[0].patches[len(models):]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.2f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_lhs
axes[1].bar(x_pos - bar_width/2, rmse_test_lhs, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, rmse_val_lhs, bar_width, label='Train', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Model', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(models, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)

# Annotate bars for results_lhs
for bars in [axes[1].patches[:len(models)], axes[1].patches[len(models):]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.2f}', 
                     ha='center', va='bottom', fontsize=14)

# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("Plots/no_opt_model_comparison_ran_lhs_rmse_7.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %%
# Extract data for GBR model (assuming it's the first row in both DataFrames)
# gbr_results_ran = wag_ran.iloc[1, 1:]  # Skip the "Models" column
# gbr_results_lhs = wag_lhs.iloc[1, 1:]

# Define test and validation data for both datasets
rmse_test_ran = np.array([wag_ran.iloc[1, 7], wag_ran_ran.iloc[1, 7], wag_gr_ran.iloc[1, 7], wag_pso_ran.iloc[1, 7]]) / 1000  # Test results
rmse_val_ran = np.array([wag_ran.iloc[1, 22], wag_ran_ran.iloc[1, 22], wag_gr_ran.iloc[1, 22], wag_pso_ran.iloc[1, 22]]) / 1000 # Validation results
rmse_test_lhs = np.array([wag_lhs.iloc[1, 7], wag_ran_lhs.iloc[1, 7], wag_gr_lhs.iloc[1, 7], wag_pso_lhs.iloc[1, 7]]) / 1000
rmse_val_lhs = np.array([wag_lhs.iloc[1, 22], wag_ran_lhs.iloc[1, 22], wag_gr_lhs.iloc[1, 22], wag_pso_lhs.iloc[1, 22]]) / 1000

# Define optimization methods and bar positions
opt_methods = ["No-opt", "Random", "Grid", "PSO"]
x_pos = np.arange(len(opt_methods))

bar_width = 0.35

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Set up Matplotlib figure and subplots
axes[0].bar(x_pos - bar_width/2, rmse_test_ran, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, rmse_val_ran, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Optimization Method', fontsize=18)
axes[0].set_ylabel('$RMSE (MSCF)$', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(opt_methods, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_ran
for bars in [axes[0].patches[:4], axes[0].patches[4:]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.2f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_lhs
axes[1].bar(x_pos - bar_width/2, rmse_test_lhs, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, rmse_val_lhs, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Optimization Method', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(opt_methods, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)

# Annotate bars for results_lhs
for bars in [axes[1].patches[:4], axes[1].patches[4:]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.2f}', 
                     ha='center', va='bottom', fontsize=14)

# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("Plots/gbr_model_comparison_ran_lhs_rmse.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # EDA Oil & Gas (WAG)

# %%
# Extract data for GBR model (assuming it's the first row in both DataFrames)

# Define test and validation data for both datasets
r2_test_oil = np.array([wag_ran_ran.iloc[1, 3], wag_gr_ran.iloc[1, 3], wag_pso_ran.iloc[1, 3]])  # Test results
r2_val_oil = np.array([wag_ran_ran.iloc[1, 18], wag_gr_ran.iloc[1, 18], wag_pso_ran.iloc[1, 18]])  # Validation results
r2_test_gas = np.array([wag_ran_ran.iloc[1, 2], wag_gr_ran.iloc[1, 2], wag_pso_ran.iloc[1, 2]])
r2_val_gas = np.array([wag_ran_ran.iloc[1, 17], wag_gr_ran.iloc[1, 17], wag_pso_ran.iloc[1, 17]])

# Define optimization methods and bar positions
opt_methods = ["Random", "Grid", "PSO"]
x_pos = np.arange(len(opt_methods))

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Bar width and spacing
bar_width = 0.4

# Left subplot: results_oil
axes[0].bar(x_pos - bar_width/2, r2_test_oil, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, r2_val_oil, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Optimization Method', fontsize=18)
axes[0].set_ylabel('$R^{2}$ Score', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(opt_methods, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc="lower left", fontsize=16)

# Annotate bars for results_oil
for bars in [axes[0].patches[:3], axes[0].patches[3:]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_gas
axes[1].bar(x_pos - bar_width/2, r2_test_gas, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, r2_val_gas, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Optimization Method', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(opt_methods, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)
#axes[1].legend(loc="lower left", fontsize=12)

# Annotate bars for results_gas
for bars in [axes[1].patches[:3], axes[1].patches[3:]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)


# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("Plots/wag_oil_gas.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# # EDA Oil & Gas (SAG)

# %%
sag_pso_ran
# Out:
#   Models  test_qg_R²_test  test_qo_R²_test  val_qg_R²_test  val_qo_R²_test  \
# 0     DT         0.968463         0.988570             NaN             NaN
# 1    GBR         0.993138         0.997059             NaN             NaN
# 2    KNN         0.994104         0.996341             NaN             NaN
# 3     RF         0.990146         0.994917             NaN             NaN
#
#    test_qg_RMSE_test  test_qo_RMSE_test  val_qg_RMSE_test  val_qo_RMSE_test  \
# 0      372968.332865      305865.202954               NaN               NaN
# 1      173975.542891      155150.008659               NaN               NaN
# 2      161263.616846      173055.163064               NaN               NaN
# 3      208484.565772      203961.583196               NaN               NaN
#
#    test_qg_R²_val  test_qo_R²_val  val_qg_R²_val  val_qo_R²_val  \
# 0             NaN             NaN       0.981649       0.992674
# 1             NaN             NaN       0.985179       0.996308
# ...

# %%
# Extract data for GBR model (assuming it's the first row in both DataFrames)

# Define test and validation data for both datasets
r2_test_oil = np.array([sag_ran_ran.iloc[1, 2], sag_gr_ran.iloc[1, 2], sag_pso_ran.iloc[1, 2]])  # Test results
r2_val_oil = np.array([sag_ran_ran.iloc[1, 12], sag_gr_ran.iloc[1, 12], sag_pso_ran.iloc[1, 12]])  # Validation results
r2_test_gas = np.array([sag_ran_ran.iloc[1, 1], sag_gr_ran.iloc[1, 1], sag_pso_ran.iloc[1, 2]])
r2_val_gas = np.array([sag_ran_ran.iloc[1, 11], sag_gr_ran.iloc[1, 11], sag_pso_ran.iloc[1, 11]])

# Define optimization methods and bar positions
opt_methods = ["Random", "Grid", "PSO"]
x_pos = np.arange(len(opt_methods))

# Set up Matplotlib figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Bar width and spacing
bar_width = 0.4

# Left subplot: results_oil
axes[0].bar(x_pos - bar_width/2, r2_test_oil, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[0].bar(x_pos + bar_width/2, r2_val_oil, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[0].set_title('a)', fontsize=20, weight='bold')
axes[0].set_xlabel('Optimization Method', fontsize=18)
axes[0].set_ylabel('$R^{2}$ Score', fontsize=18)
axes[0].set_xticks(x_pos)
axes[0].set_xticklabels(opt_methods, fontsize=16)
axes[0].tick_params(axis='both', labelsize=16)
axes[0].legend(loc=0, fontsize=16)

# Annotate bars for results_oil
for bars in [axes[0].patches[:3], axes[0].patches[3:]]:
    for bar in bars:
        height = bar.get_height()
        axes[0].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)

# Right subplot: results_gas
axes[1].bar(x_pos - bar_width/2, r2_test_gas, bar_width, label='Test', color='#1f77b4', alpha=0.8)
axes[1].bar(x_pos + bar_width/2, r2_val_gas, bar_width, label='Validation', color='#ff7f0e', alpha=0.8)
axes[1].set_title('b)', fontsize=20, weight='bold')
axes[1].set_xlabel('Optimization Method', fontsize=18)
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(opt_methods, fontsize=16)
axes[1].tick_params(axis='both', labelsize=16)
#axes[1].legend(loc=0, fontsize=12)

# Annotate bars for results_gas
for bars in [axes[1].patches[:3], axes[1].patches[3:]]:
    for bar in bars:
        height = bar.get_height()
        axes[1].text(bar.get_x() + bar.get_width()/2, height + 0.01, f'{height:.3f}', 
                     ha='center', va='bottom', fontsize=14)


# Adjust layout and save the plot
fig.tight_layout()
plt.savefig("Plots/sag_oil_gas.png", dpi=300, format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
